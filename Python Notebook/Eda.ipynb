# %% [markdown]
# # Spotify Data Analysis

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing the Dataset 
df = pd.read_csv('data.csv', encoding='ISO-8859-1')
df.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# ...

# %%
#Information about data
print('The data has a shape of ' , df.shape)
print("\n\n")
print(df.info())
# Out:
# The data has a shape of  (4600, 29)
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   object
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4487 non-null   object
#  8   Spotify Playlist Count      4530 non-null   object
#  9   Spotify Playlist Reach      4528 non-null   object
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   object
# ...

# %%
#checking for missing values 
df.isnull().sum().sort_values(ascending=False)
# Out:
# TIDAL Popularity              4600
# Soundcloud Streams            3333
# SiriusXM Spins                2123
# Pandora Track Stations        1268
# TikTok Posts                  1173
# Pandora Streams               1106
# Amazon Playlist Count         1055
# YouTube Playlist Reach        1009
# TikTok Views                   981
# TikTok Likes                   980
# Deezer Playlist Reach          928
# Deezer Playlist Count          921
# Spotify Popularity             804
# Shazam Counts                  577
# Apple Music Playlist Count     561
# AirPlay Spins                  498
# YouTube Likes                  315
# YouTube Views                  308
# Spotify Streams                113
# Spotify Playlist Reach          72
# Spotify Playlist Count          70
# Artist                           5
# Track                            0
# Album Name                       0
# Track Score                      0
# All Time Rank                    0
# ISRC                             0
# ...

# %%
df.drop(columns=['Soundcloud Streams','TIDAL Popularity'], axis=1,inplace=True)

# %%
df.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  \
# ...

# %%
#values in spotify streams contain comma that is why they are stored as string so we are changing that 
df = df.map(lambda x: x.replace(',','') if isinstance(x,str) else x)

# %%
for x in df.columns[6:]:
    df[x] = pd.to_numeric(df[x])
    print(df[x].dtype)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   object
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4487 non-null   float64
#  8   Spotify Playlist Count      4530 non-null   float64
#  9   Spotify Playlist Reach      4528 non-null   float64
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   float64
#  12  YouTube Likes               4285 non-null   float64
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# SiriusXM Spins                2123
# Pandora Track Stations        1268
# TikTok Posts                  1173
# Pandora Streams               1106
# Amazon Playlist Count         1055
# YouTube Playlist Reach        1009
# TikTok Views                   981
# TikTok Likes                   980
# Deezer Playlist Reach          928
# Deezer Playlist Count          921
# Spotify Popularity             804
# Shazam Counts                  577
# Apple Music Playlist Count     561
# AirPlay Spins                  498
# YouTube Likes                  315
# YouTube Views                  308
# Spotify Streams                113
# Spotify Playlist Reach          72
# Spotify Playlist Count          70
# Artist                           5
# Track                            0
# Album Name                       0
# Track Score                      0
# All Time Rank                    0
# ISRC                             0
# Release Date                     0
# Explicit Track                   0
# ...

# %%
# Dropping the null columns and irrelevent columns only 

to_drop = ['SiriusXM Spins' ,'Pandora Track Stations' , 'Pandora Streams' , 'Amazon Playlist Count' , 'Deezer Playlist Reach' , 'Deezer Playlist Count' , 'AirPlay Spins' ]
df.drop(columns=to_drop, inplace=True , index = 1)

# %%
df.head()
# Out:
#                         Track                    Album Name         Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single  Tommy Richman
# 2  i like the way you kiss me    I like the way you kiss me        Artemas
# 3                     Flowers              Flowers - Single    Miley Cyrus
# 4                     Houdini                       Houdini         Eminem
# 5                 Lovin On Me                   Lovin On Me    Jack Harlow
#
#   Release Date          ISRC All Time Rank  Track Score  Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     3.904709e+08
# 2    3/19/2024  QZJ842400387             3        538.4     6.013093e+08
# 3    1/12/2023  USSM12209777             4        444.9     2.031281e+09
# 4    5/31/2024  USUG12403398             5        423.3     1.070349e+08
# 5   11/10/2023  USAT22311371             6        410.1     6.706654e+08
#
#    Spotify Playlist Count  Spotify Playlist Reach  Spotify Popularity  \
# ...

# %%
from sklearn.impute import SimpleImputer
# Create an instance of the imputer
imputer = SimpleImputer(strategy='mean')
# Get the numerical columns
numerical_columns = df.select_dtypes(include=[np.number]).columns

# Apply imputation only to numerical columns
df[numerical_columns] = imputer.fit_transform(df[numerical_columns])

# %%
df.head()
# Out:
#                         Track                    Album Name         Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single  Tommy Richman
# 2  i like the way you kiss me    I like the way you kiss me        Artemas
# 3                     Flowers              Flowers - Single    Miley Cyrus
# 4                     Houdini                       Houdini         Eminem
# 5                 Lovin On Me                   Lovin On Me    Jack Harlow
#
#   Release Date          ISRC All Time Rank  Track Score  Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     3.904709e+08
# 2    3/19/2024  QZJ842400387             3        538.4     6.013093e+08
# 3    1/12/2023  USSM12209777             4        444.9     2.031281e+09
# 4    5/31/2024  USUG12403398             5        423.3     1.070349e+08
# 5   11/10/2023  USAT22311371             6        410.1     6.706654e+08
#
#    Spotify Playlist Count  Spotify Playlist Reach  Spotify Popularity  \
# ...

# %%
df.isnull().sum()
# Out:
# Track                         0
# Album Name                    0
# Artist                        5
# Release Date                  0
# ISRC                          0
# All Time Rank                 0
# Track Score                   0
# Spotify Streams               0
# Spotify Playlist Count        0
# Spotify Playlist Reach        0
# Spotify Popularity            0
# YouTube Views                 0
# YouTube Likes                 0
# TikTok Posts                  0
# TikTok Likes                  0
# TikTok Views                  0
# YouTube Playlist Reach        0
# Apple Music Playlist Count    0
# Shazam Counts                 0
# Explicit Track                0
# dtype: int64

# %%
# Now the only column left is Artist and we can't impute that So best way is to drop that
df = df.dropna()

# %%
df.head()
# Out:
#                         Track                    Album Name         Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single  Tommy Richman
# 2  i like the way you kiss me    I like the way you kiss me        Artemas
# 3                     Flowers              Flowers - Single    Miley Cyrus
# 4                     Houdini                       Houdini         Eminem
# 5                 Lovin On Me                   Lovin On Me    Jack Harlow
#
#   Release Date          ISRC All Time Rank  Track Score  Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     3.904709e+08
# 2    3/19/2024  QZJ842400387             3        538.4     6.013093e+08
# 3    1/12/2023  USSM12209777             4        444.9     2.031281e+09
# 4    5/31/2024  USUG12403398             5        423.3     1.070349e+08
# 5   11/10/2023  USAT22311371             6        410.1     6.706654e+08
#
#    Spotify Playlist Count  Spotify Playlist Reach  Spotify Popularity  \
# ...

# %% [markdown]
# # Visualisations

# %%
df['Release Date'] = pd.to_datetime(df['Release Date'],format='%m/%d/%Y')
df['year'] = df['Release Date'].dt.year
timedf = df.groupby('year')['Track'].size().reset_index()
tdf = timedf[timedf['year']>2005]
tdf['year'] = tdf['year'].astype("str")
plt.figure(20)
plt.bar(tdf['year'], tdf['Track'])
plt.xticks(rotation=45)
plt.show()

# %%
dff =df.copy()
dff['Explicit Track'] = dff['Explicit Track'].replace({0: 'Not Explicit', 1: 'Explicit'})
print(dff["Explicit Track"].value_counts())
plt.pie(df['Explicit Track'].value_counts() , labels=['Not Explicit' , 'Explicit'])
plt.show()
# Out:
# Explicit Track
# Not Explicit    2944
# Explicit        1650
# Name: count, dtype: int64
